# %%
import polars as pl
import pandas as pd

import matplotlib.pyplot as plt

# %%
whisky_df = pd.read_csv("input/Meta-Critic Whisky Database – Selfbuilts Whisky Analysis.csv")

# %%
whisky_df
# Out:
#                                                  Whisky  Meta Critic  STDEV  \
# 0     Macallan 10yo Full Proof 57% 1980 (OB, Giovine...         9.58   0.25
# 1                                   Ledaig 42yo Dusgadh         9.48   0.19
# 2     Laphroaig 27yo 57.4% 1980-2007 (OB, 5 Oloroso ...         9.42   0.24
# 3                                      Glenfarclas 40yo         9.29   0.26
# 4                              Amrut Spectrum (Batch 1)         9.21   0.25
# ...                                                 ...          ...    ...
# 1807                               Jim Beam White Label         7.63   0.57
# 1808                        Rebel Yell Kentucky Bourbon         7.55   0.67
# 1809                   Jim Beam Red Stag (Black Cherry)         7.34   1.01
# 1810                                     Virginia Black         7.19   1.23
# 1811                        Early Times Kentucky Whisky         7.10   0.48
#
#        #    Cost            Class Super Cluster Cluster   Country       Type
# 0      3  $$$$$+  SingleMalt-like           ABC       A  Scotland       Malt
# 1      4  $$$$$+  SingleMalt-like           ABC       C  Scotland       Malt
# 2      4  $$$$$+  SingleMalt-like           ABC       C  Scotland       Malt
# 3     17  $$$$$+  SingleMalt-like           ABC       A  Scotland       Malt
# 4     14   $$$$$  SingleMalt-like           ABC       C     India       Malt
# ...   ..     ...              ...           ...     ...       ...        ...
# 1807  22       $     Bourbon-like           NaN      R2       USA    Bourbon
# 1808  14       $     Bourbon-like           NaN      R0       USA    Bourbon
# 1809   4       $     Bourbon-like           NaN     NaN       USA  Flavoured
# 1810   6      $$     Bourbon-like           NaN      R2       USA    Bourbon
# 1811   7       $     Bourbon-like           NaN      R1       USA    Bourbon
#
# [1812 rows x 10 columns]

# %%
print(whisky_df.describe())
# Out:
#        Meta Critic        STDEV            #
# count  1812.000000  1812.000000  1812.000000
# mean      8.554785     0.383433    11.026490
# std       0.396355     0.193726     6.990991
# min       6.470000     0.010000     3.000000
# 25%       8.337500     0.267500     5.000000
# 50%       8.610000     0.350000     9.000000
# 75%       8.830000     0.460000    15.000000
# max       9.580000     2.640000    34.000000

# %%
category_counts = whisky_df["Super Cluster"].value_counts().reset_index()
category_counts.columns = ["Super Cluster", "count"]
category_counts = category_counts.sort_values(by="Super Cluster", ascending=True)
print(category_counts)
# Out:
#   Super Cluster  count
# 0           ABC    383
# 1            EF    284
# 2            GH    222
# 3             I    185
# 4             J    138

# %%
category_counts = whisky_df["Cluster"].value_counts().reset_index()
category_counts.columns = ["Cluster", "count"]
category_counts = category_counts.sort_values(by="Cluster", ascending=True)
print(category_counts)
# Out:
#    Cluster  count
# 5        A    106
# 10       B     55
# 1        C    223
# 0        E    239
# 12       F     45
# 3        G    148
# 6        H     73
# 2        I    185
# 4        J    138
# 13      R0     29
# 7       R1     71
# 8       R2     68
# 11      R3     48
# 9       R4     64

# %%
category_counts = whisky_df["Class"].value_counts().reset_index()
category_counts.columns = ["Class", "count"]
category_counts = category_counts.sort_values(by="count", ascending=True)
print(category_counts)
# Out:
#              Class  count
# 3      Scotch-like    135
# 2     Bourbon-like    228
# 1         Rye-like    237
# 0  SingleMalt-like   1212

# %%
category_counts = whisky_df["Type"].value_counts().reset_index()
category_counts.columns = ["Type", "count"]
category_counts = category_counts.sort_values(by="count", ascending=False)
print(category_counts)
# Out:
#         Type  count
# 0       Malt   1191
# 1      Blend    309
# 2    Bourbon    212
# 3        Rye     88
# 4      Grain      7
# 5      Wheat      2
# 6     Barley      1
# 7    Whiskey      1
# 8  Flavoured      1

# %%
category_counts = whisky_df["Country"].value_counts().reset_index()
category_counts.columns = ["Country", "count"]
category_counts = category_counts.sort_values(by="count", ascending=False)
print(category_counts)
# Out:
#          Country  count
# 0       Scotland    965
# 1            USA    304
# 2         Canada    221
# 3        Ireland     83
# 4          Japan     79
# 5         Sweden     63
# 6          India     38
# 7         Taiwan     22
# 8          Wales      8
# 9        Finland      7
# 10   Switzerland      6
# 11      Tasmania      5
# 12   Netherlands      4
# 13  South Africa      3
# 14       England      2
# 15       Belgium      1
# 16        France      1

# %%
whisky_df[whisky_df['Whisky'].str.contains("Glenmorangie", case=False)].sort_values(by="Meta Critic", ascending=False)
# Out:
#                                       Whisky  Meta Critic  STDEV   #    Cost  \
# 71                       Glenmorangie Signet         8.95   0.35  28   $$$$$
# 418                     Glenmorangie Ealanta         8.89   0.26  19  $$$$$+
# 435                       Glenmorangie Astar         8.83   0.33  21   $$$$$
# 134                    Glenmorangie Companta         8.82   0.56  14   $$$$$
# 156                     Glenmorangie Bacalta         8.78   0.32   8   $$$$$
# 702  Glenmorangie Spios Private Edition No 9         8.76   0.24  12    $$$$
# 703                      Glenmorangie Tusail         8.76   0.32  16   $$$$$
# 478                        Glenmorangie 18yo         8.72   0.27  21   $$$$$
# 187                 Glenmorangie Nectar d'Or         8.70   0.29  27    $$$$
# 211                  Glenmorangie The Taghta         8.66   0.33  11   $$$$$
# 728                Glenmorangie The Tarlogan         8.61   0.33   6    $$$$
# 255                Glenmorangie Quinta Ruban         8.58   0.42  30     $$$
# 259                     Glenmorangie Dornoch         8.57   0.47   9    $$$$
# 275    Glenmorangie A Midwinter Night’s Dram         8.53   0.31   8   $$$$$
# 289                      Glenmorangie Duthac         8.50   0.27   9    $$$$
# 306                     Glenmorangie Milsean         8.44   0.38  13   $$$$$
# 318                   Glenmorangie The Tayne         8.40   0.36  11    $$$$
# 784                        Glenmorangie 10yo         8.40   0.41  29     $$$
# 320                     Glenmorangie Lasanta         8.39   0.36  28     $$$
#
#                Class Super Cluster Cluster   Country  Type
# 71   SingleMalt-like           ABC       C  Scotland  Malt
# 418  SingleMalt-like            EF       F  Scotland  Malt
# 435  SingleMalt-like            EF       E  Scotland  Malt
# 134  SingleMalt-like           ABC       C  Scotland  Malt
# 156  SingleMalt-like           ABC       C  Scotland  Malt
# 702  SingleMalt-like            GH       G  Scotland  Malt
# 703  SingleMalt-like            GH       G  Scotland  Malt
# 478  SingleMalt-like            EF       E  Scotland  Malt
# 187  SingleMalt-like           ABC       A  Scotland  Malt
# 211  SingleMalt-like           ABC       C  Scotland  Malt
# 728  SingleMalt-like            GH       H  Scotland  Malt
# 255  SingleMalt-like           ABC       B  Scotland  Malt
# 259  SingleMalt-like           ABC       C  Scotland  Malt
# 275  SingleMalt-like           ABC       A  Scotland  Malt
# 289  SingleMalt-like           ABC       C  Scotland  Malt
# 306  SingleMalt-like           ABC       A  Scotland  Malt
# 318  SingleMalt-like           ABC       C  Scotland  Malt
# 784  SingleMalt-like            GH       G  Scotland  Malt
# 320  SingleMalt-like           ABC       A  Scotland  Malt

# %% [markdown]
# # Dump data into mongo

# %%
from pprint import pprint

from dotenv import load_dotenv
import os

from pymongo import MongoClient
from datetime import datetime
import pytz

# %%
# Directly set the path to your .env file
env_path = r"../Local/mongo.env"

# Load the .env file
load_dotenv(dotenv_path=env_path)

# Access the environment variables
username = os.getenv("MONGO_USERNAME")
password = os.getenv("MONGO_PASSWORD")
cluster_url = os.getenv("CLUSTER_URL")

# %%
from pymongo import MongoClient

database = "domain_hr"

# Replace with your actual connection string
connection_string = f"mongodb://{username}:{password}@{cluster_url}?authSource=admin&replicaSet=rs0&directConnection=true"

# Initialize the MongoClient
client = MongoClient(connection_string)

# Access a specific database
db = client["test_db"]

# Access a specific collection
collection = db["w_cluster"]
# Out:
# {'#': 3,
#  'Class': 'SingleMalt-like',
#  'Cluster': 'A',
#  'Cost': '$$$$$+',
#  'Country': 'Scotland',
#  'Meta Critic': 9.58,
#  'STDEV': 0.25,
#  'Super Cluster': 'ABC',
#  'Type': 'Malt',
#  'Whisky': 'Macallan 10yo Full Proof 57% 1980 (OB, Giovinetti & Figli)',
#  '_id': ObjectId('6790fe6a1f30026003b97f19')}

# %%
# Test the connection by printing the first document
pprint(collection.find_one())
# Out:
# {'#': 3,
#  'Class': 'SingleMalt-like',
#  'Cluster': 'A',
#  'Cost': '$$$$$+',
#  'Country': 'Scotland',
#  'Meta Critic': 9.58,
#  'STDEV': 0.25,
#  'Super Cluster': 'ABC',
#  'Type': 'Malt',
#  'Whisky': 'Macallan 10yo Full Proof 57% 1980 (OB, Giovinetti & Figli)',
#  '_id': ObjectId('6790fe6a1f30026003b97f19')}

# %%
the_good_ones = collection.find({
    "$and": [
        {'Meta Critic': {"$gte":9.3}},
        {'#': {"$gte": 5}}
    ]
    })

for x in the_good_ones:
    pprint(x)
# Out:
# {'#': 7,
#  'Class': 'SingleMalt-like',
#  'Cluster': 'I',
#  'Cost': '$$$$$+',
#  'Country': 'Scotland',
#  'Meta Critic': 9.51,
#  'STDEV': 0.23,
#  'Super Cluster': 'I',
#  'Type': 'Malt',
#  'Whisky': 'Port Ellen 2nd release 24yo 59.35%',
#  '_id': ObjectId('6790fe6a1f30026003b98292')}
# {'#': 5,
#  'Class': 'SingleMalt-like',
#  'Cluster': 'I',
#  'Cost': '$$$$$+',
#  'Country': 'Scotland',
#  'Meta Critic': 9.48,
#  'STDEV': 0.12,
#  'Super Cluster': 'I',
#  'Type': 'Malt',
#  'Whisky': 'Port Ellen 9th release 30yo',
#  '_id': ObjectId('6790fe6a1f30026003b98293')}
# {'#': 5,
#  'Class': 'SingleMalt-like',
#  'Cluster': 'I',
#  'Cost': '$$$$$+',
#  'Country': 'Scotland',
#  'Meta Critic': 9.38,
#  'STDEV': 0.54,
#  'Super Cluster': 'I',
#  'Type': 'Malt',
#  'Whisky': 'Port Ellen 10th release 31yo',
#  '_id': ObjectId('6790fe6a1f30026003b98296')}
# {'#': 6,
#  'Class': 'SingleMalt-like',
#  'Cluster': 'I',
#  'Cost': '$$$$$+',
#  'Country': 'Scotland',
#  'Meta Critic': 9.34,
#  'STDEV': 0.46,
#  'Super Cluster': 'I',
#  'Type': 'Malt',
#  'Whisky': 'Port Ellen 11th release 32yo',
#  '_id': ObjectId('6790fe6a1f30026003b98298')}
# {'#': 19,
#  'Class': 'SingleMalt-like',
#  'Cluster': 'I',
#  'Cost': '$$$$$+',
#  'Country': 'Scotland',
#  'Meta Critic': 9.32,
#  'STDEV': 0.31,
#  'Super Cluster': 'I',
#  'Type': 'Malt',
#  'Whisky': 'Port Ellen (all OB releases)',
#  '_id': ObjectId('6790fe6a1f30026003b9829b')}
# {'#': 14,
#  'Class': 'SingleMalt-like',
#  'Cluster': 'I',
#  'Cost': '$$$$$+',
#  'Country': 'Scotland',
#  'Meta Critic': 9.3,
#  'STDEV': 0.25,
#  'Super Cluster': 'I',
#  'Type': 'Malt',
#  'Whisky': 'Caol Ila 30yo',
#  '_id': ObjectId('6790fe6a1f30026003b9829c')}
# {'#': 13,
#  'Class': 'SingleMalt-like',
#  'Cluster': 'J',
#  'Cost': '$$$$$+',
#  'Country': 'Scotland',
#  'Meta Critic': 9.43,
#  'STDEV': 0.3,
#  'Super Cluster': 'J',
#  'Type': 'Malt',
#  'Whisky': 'Brora 35yo',
#  '_id': ObjectId('6790fe771f30026003b9834b')}
# {'#': 20,
#  'Class': 'SingleMalt-like',
#  'Cluster': 'J',
#  'Cost': '$$$$$+',
#  'Country': 'Scotland',
#  'Meta Critic': 9.39,
#  'STDEV': 0.27,
#  'Super Cluster': 'J',
#  'Type': 'Malt',
#  'Whisky': 'Brora 30yo',
#  '_id': ObjectId('6790fe771f30026003b9834c')}
# {'#': 5,
#  'Class': 'Rye-like',
#  'Cost': '$$$$$',
#  'Country': 'Canada',
#  'Meta Critic': 9.38,
#  'STDEV': 0.36,
#  'Type': 'Blend',
#  'Whisky': 'Mister Sam Tribute Whisky',
#  '_id': ObjectId('6790fe771f30026003b9845e')}

# %%
# Insert the document into the MongoDB collection
result = collection.insert_one(document)

# Print the ID of the inserted document
print(f"Document inserted with _id: {result.inserted_id}")
# Out:
# Document inserted with _id: 67596e8c74301fbaa43ef295
